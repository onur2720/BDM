# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import re

pattern = r'[,\t;]+'

# Read the CSV file
df = pd.read_csv('train_v3.csv', sep = ";")

# Remove potential leading/trailing spaces from column names
df.columns = df.columns.str.strip()


# Read the train file

df2 = df[['Monthly rent payment','=1 Overcrowding by rooms','=1 has toilet in the household',"=1 if the household has refrigerator",'Total males in the household','Total persons in the household','years of schooling','=1 if predominant material on the outside wall is waste material','=1 if no floor at the household','=1 if the house has ceiling','=1 if no water provision','=1 no electricity in the dwelling','=1 no main source of energy used for cooking (no kitchen)','=1 if male','=1 if divorced','=1 if widow/er','=1 if single','Household level identifier','Number of children 0 to 19 in household','Dependency rate','years of education of male head of household','years of education of female head of household','# persons per room','=1 own and fully paid house','=1 rented','=1 region Central','=1 region Chorotega','=1 region Brunca','=1 region Huetar Norte','=1 zona urbana','Age in years','Target']]

df3= df[['=1 if the house has ceiling','number of all rooms in the house','=1 Overcrowding by rooms','=1 has toilet in the household',"=1 if the household has refrigerator",'Total males in the household','Total persons in the household','=1 if predominant material on the outside wall is waste material','=1 if no floor at the household','=1 if no water provision','=1 no electricity in the dwelling','Target']]
df4= df[["=1 no main source of energy used for cooking (no kitchen)",'=1 if male','=1 if divorced','=1 if widow/er','=1 if single','Household level identifier','Dependency rate','# persons per room','=1 own and fully paid house','=1 rented','=1 zona urbana','Age in years','Target']]
df5 = df[['=1 region Central','=1 region Chorotega','=1 region Brunca','=1 region Huetar Norte','=1 region Huetar Atlantica','=1 region Paci­fico central','=1 zona urbana','Age in years','Target']]
df6= df[['Number of children 0 to 19 in household','average years of education for adults (18+)','owns a tablet','years of education of male head of household','persons younger than 12 years of age','years of schooling','Target']]
df7 = df[['=1 if floor are good','=1 if predominant material on the outside wall is block or brick','escolari squared','edjefe squared','hogar_nin squared','=1 if mobile phone','# of mobile phones','Total females in the household','Target']]
df8 = df[['edjefe','edjefa','number of bedrooms','Target']]

fig, ax = plt.subplots()

corr_matrix = df8.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# /var/folders/dw/3_fby8bx2k11dqpxfrbyqhb40000gp/T/ipykernel_7248/1619158989.py:29: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df8.corr()
